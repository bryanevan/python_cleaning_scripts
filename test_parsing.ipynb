# %%
import pandas as pd
import re
import json
import os
from datetime import datetime
import usaddress

def load_json_data(json_path):
    """Load JSON data from a file."""
    with open(json_path, 'r') as f:
        return json.load(f)


def compile_street_suffix_regex(suffix_file_path):
    """Compile regex pattern for street suffixes."""
    street_suffixes = load_json_data(suffix_file_path)
    all_suffixes = set()
    for suffix in street_suffixes:
        all_suffixes.update(suffix["abbrs"])
    pattern = '|'.join(re.escape(sfx) for sfx in all_suffixes)
    return re.compile(r'\b(?:' + pattern + r')\b', re.IGNORECASE)
    

def extract_state_from_address(address, states_data):
    """Identifies the state abbreviation from the address."""
    if pd.isnull(address):
        return None
    normalized_address = str(address).lower()
    for state_abbr, state_name in states_data.items():
        if state_abbr.lower() in normalized_address or state_name.lower() in normalized_address:
            return state_abbr
    return None
    

def extract_city_from_address(address):
    """Extracts city from address using the usaddress library, with error handling for complex addresses."""
    if pd.isnull(address):
        return None
    try:
        parsed_address, _ = usaddress.tag(address)
        return parsed_address.get('PlaceName')
    except usaddress.RepeatedLabelError as e:
        # Fallback: Attempt to extract city from the parsed tokens directly in case of RepeatedLabelError
        tokens = e.parsed_string
        for token, label in tokens:
            if label == 'PlaceName':
                return token
        print(f"Error parsing address '{address}': {e}")
    except Exception as e:
        print(f"An error occurred during address parsing: {e}")
    return None
    

def extract_street(address, suffix_regex):
    """Extract street name from address."""
    if pd.isnull(address):
        return None
    match = suffix_regex.search(str(address))
    if match:
        end_index = match.end()
        street_address_with_suffix = address[:end_index]
        return street_address_with_suffix.replace(',', '').strip()
    return None
    

def extract_zip_code(address):
    """Extract ZIP code from address."""
    if pd.isnull(address):
        return None
    match = re.search(r'\b\d{5}\b', str(address))
    if match:
        return match.group()
    return None


def filter_columns(df, base_columns, new_columns):
    """Filters the DataFrame to keep specified columns."""
    columns_to_keep = base_columns + new_columns
    return df[columns_to_keep]


def parse_address_data(file_path, suffix_regex, states_data):
    """Main parsing function to process the address data."""
    df = pd.read_csv(file_path)
    df['Street_Address'] = df['principal_address'].apply(lambda x: extract_street(x, suffix_regex))
    df['City'] = df['principal_address'].apply(extract_city_from_address)  # Utilizes usaddress for city extraction
    df['ZIP_Code'] = df['principal_address'].apply(extract_zip_code)
    df['State'] = df['principal_address'].apply(lambda x: extract_state_from_address(x, states_data))
    # Specify the base and new columns to keep
    base_columns = ['name', 'principal_name']
    new_columns = ['Street_Address', 'City', 'ZIP_Code', 'State']
    df_filtered = filter_columns(df, base_columns, new_columns)
    return df_filtered


def export_parsed_data(df, input_file_path, directory_path):
    """Export parsed DataFrame to CSV."""
    base_name = os.path.basename(input_file_path)
    name, ext = os.path.splitext(base_name)
    output_file_name = f"{name}_parsed{ext}_test{ext}"
    output_file_path = os.path.join(directory_path, output_file_name)
    df.to_csv(output_file_path, index=False)
    return output_file_path
    
file_path = '/Users/bryanevan/Downloads/Phoenix_forecasa.csv'
suffix_file_path = '/Users/bryanevan/CF/ANACONDA/python_cleaning_scripts/json/street_suffix.json'
cities_aliases_path = '/Users/bryanevan/CF/ANACONDA/python_cleaning_scripts/json/cities_and_aliases.json'
states_json_path = '/Users/bryanevan/CF/ANACONDA/python_cleaning_scripts/json/states.json'
directory_path = '/Users/bryanevan/Downloads'

# Load data
states_data = {k: v for d in load_json_data(states_json_path) for k, v in d.items()}

# Process and export data
suffix_regex_pattern = compile_street_suffix_regex(suffix_file_path)
parsed_df = parse_address_data(file_path, suffix_regex_pattern, states_data)
new_file_path = export_parsed_data(parsed_df, file_path, directory_path)

print(f"Exported parsed data to: {new_file_path}")
# Out:
# Error parsing address 'Westwood College - Los Angeles, 3250, Wilshire Boulevard, Koreatown, Los Angeles, Los Angeles County, California, 90010, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  Westwood College - Los Angeles, 3250, Wilshire Boulevard, Koreatown, Los Angeles, Los Angeles County, California, 90010, United States
# PARSED TOKENS:    [('Westwood', 'Recipient'), ('College', 'Recipient'), ('Los', 'Recipient'), ('Angeles,', 'Recipient'), ('3250,', 'AddressNumber'), ('Wilshire', 'StreetName'), ('Boulevard,', 'StreetNamePostType'), ('Koreatown,', 'Recipient'), ('Los', 'Recipient'), ('Angeles,', 'Recipient'), ('Los', 'Recipient'), ('Angeles', 'Recipient'), ('County,', 'Recipient'), ('California,', 'Recipient'), ('90010,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '7036, Goforth Street, Foster Place, Houston, Harris County, Texas, 77021, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  7036, Goforth Street, Foster Place, Houston, Harris County, Texas, 77021, United States
# PARSED TOKENS:    [('7036,', 'AddressNumber'), ('Goforth', 'StreetName'), ('Street,', 'StreetNamePostType'), ('Foster', 'BuildingName'), ('Place,', 'BuildingName'), ('Houston,', 'BuildingName'), ('Harris', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('77021,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '12509, Tabor Oaks Drive, Barker Ranch at Shady Hollow, Austin, Travis County, Texas, 78739, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  12509, Tabor Oaks Drive, Barker Ranch at Shady Hollow, Austin, Travis County, Texas, 78739, United States
# PARSED TOKENS:    [('12509,', 'AddressNumber'), ('Tabor', 'StreetName'), ('Oaks', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Barker', 'BuildingName'), ('Ranch', 'BuildingName'), ('at', 'BuildingName'), ('Shady', 'BuildingName'), ('Hollow,', 'BuildingName'), ('Austin,', 'BuildingName'), ('Travis', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('78739,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '3100, Alvin Devane Boulevard, Sunridge Park, Austin, Travis County, Texas, 78741, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  3100, Alvin Devane Boulevard, Sunridge Park, Austin, Travis County, Texas, 78741, United States
# PARSED TOKENS:    [('3100,', 'AddressNumber'), ('Alvin', 'StreetName'), ('Devane', 'StreetName'), ('Boulevard,', 'StreetNamePostType'), ('Sunridge', 'BuildingName'), ('Park,', 'BuildingName'), ('Austin,', 'BuildingName'), ('Travis', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('78741,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '1227, Bow Creek Drive, Red Bird Addition, Duncanville, Dallas County, Texas, 75116, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1227, Bow Creek Drive, Red Bird Addition, Duncanville, Dallas County, Texas, 75116, United States
# PARSED TOKENS:    [('1227,', 'AddressNumber'), ('Bow', 'StreetName'), ('Creek', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Red', 'BuildingName'), ('Bird', 'BuildingName'), ('Addition,', 'BuildingName'), ('Duncanville,', 'BuildingName'), ('Dallas', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('75116,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '12317, Scribe Drive, The Centrum, Austin, Travis County, Texas, 78759, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  12317, Scribe Drive, The Centrum, Austin, Travis County, Texas, 78759, United States
# PARSED TOKENS:    [('12317,', 'AddressNumber'), ('Scribe', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('The', 'BuildingName'), ('Centrum,', 'BuildingName'), ('Austin,', 'BuildingName'), ('Travis', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('78759,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '82, South Prospect Terrace, Colonial Village, Teaneck Township, Bergen County, New Jersey, 07666, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  82, South Prospect Terrace, Colonial Village, Teaneck Township, Bergen County, New Jersey, 07666, United States
# PARSED TOKENS:    [('82,', 'AddressNumber'), ('South', 'StreetNamePreDirectional'), ('Prospect', 'StreetName'), ('Terrace,', 'StreetNamePostType'), ('Colonial', 'Recipient'), ('Village,', 'Recipient'), ('Teaneck', 'Recipient'), ('Township,', 'Recipient'), ('Bergen', 'Recipient'), ('County,', 'Recipient'), ('New', 'Recipient'), ('Jersey,', 'Recipient'), ('07666,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'Guidance Residential, LLC, 11107, Sunset Hills Road, Pinecrest, Reston, Fairfax County, Virginia, 20190, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  Guidance Residential, LLC, 11107, Sunset Hills Road, Pinecrest, Reston, Fairfax County, Virginia, 20190, United States
# PARSED TOKENS:    [('Guidance', 'Recipient'), ('Residential,', 'Recipient'), ('LLC,', 'Recipient'), ('11107,', 'AddressNumber'), ('Sunset', 'StreetName'), ('Hills', 'StreetName'), ('Road,', 'StreetNamePostType'), ('Pinecrest,', 'Recipient'), ('Reston,', 'Recipient'), ('Fairfax', 'Recipient'), ('County,', 'Recipient'), ('Virginia,', 'Recipient'), ('20190,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'The UPS Store, 14747, North Northsight Boulevard, Scottsdale, Maricopa County, Arizona, 85260, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  The UPS Store, 14747, North Northsight Boulevard, Scottsdale, Maricopa County, Arizona, 85260, United States
# PARSED TOKENS:    [('The', 'Recipient'), ('UPS', 'Recipient'), ('Store,', 'Recipient'), ('14747,', 'AddressNumber'), ('North', 'StreetNamePreDirectional'), ('Northsight', 'StreetName'), ('Boulevard,', 'StreetNamePostType'), ('Scottsdale,', 'Recipient'), ('Maricopa', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85260,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '2900, McKinnon Street, Harwood District, Dallas, Dallas County, Texas, 75201, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  2900, McKinnon Street, Harwood District, Dallas, Dallas County, Texas, 75201, United States
# PARSED TOKENS:    [('2900,', 'AddressNumber'), ('McKinnon', 'StreetName'), ('Street,', 'StreetNamePostType'), ('Harwood', 'BuildingName'), ('District,', 'BuildingName'), ('Dallas,', 'BuildingName'), ('Dallas', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('75201,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '2630, Bentley Avenue, Oak Cliff, Dallas, Dallas County, Texas, 75211, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  2630, Bentley Avenue, Oak Cliff, Dallas, Dallas County, Texas, 75211, United States
# PARSED TOKENS:    [('2630,', 'AddressNumber'), ('Bentley', 'StreetName'), ('Avenue,', 'StreetNamePostType'), ('Oak', 'BuildingName'), ('Cliff,', 'BuildingName'), ('Dallas,', 'BuildingName'), ('Dallas', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('75211,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '5901, Vanderbilt Avenue, Lower Greenville, Dallas, Dallas County, Texas, 75206, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  5901, Vanderbilt Avenue, Lower Greenville, Dallas, Dallas County, Texas, 75206, United States
# PARSED TOKENS:    [('5901,', 'AddressNumber'), ('Vanderbilt', 'StreetName'), ('Avenue,', 'StreetNamePostType'), ('Lower', 'BuildingName'), ('Greenville,', 'BuildingName'), ('Dallas,', 'BuildingName'), ('Dallas', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('75206,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '24823, Corbin Gate Drive, Village of Auburn Lakes, Auburn Lakes, Harris County, Texas, 77389, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  24823, Corbin Gate Drive, Village of Auburn Lakes, Auburn Lakes, Harris County, Texas, 77389, United States
# PARSED TOKENS:    [('24823,', 'AddressNumber'), ('Corbin', 'StreetName'), ('Gate', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Village', 'BuildingName'), ('of', 'BuildingName'), ('Auburn', 'BuildingName'), ('Lakes,', 'BuildingName'), ('Auburn', 'BuildingName'), ('Lakes,', 'BuildingName'), ('Harris', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('77389,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '5023, Parkview Place, Addison, Dallas County, Texas, 75001, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  5023, Parkview Place, Addison, Dallas County, Texas, 75001, United States
# PARSED TOKENS:    [('5023,', 'AddressNumber'), ('Parkview', 'StreetName'), ('Place,', 'StreetNamePostType'), ('Addison,', 'BuildingName'), ('Dallas', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('75001,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '2700, Patriot Boulevard, Glenview, Northfield Township, Cook County, Illinois, 60026, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  2700, Patriot Boulevard, Glenview, Northfield Township, Cook County, Illinois, 60026, United States
# PARSED TOKENS:    [('2700,', 'AddressNumber'), ('Patriot', 'StreetName'), ('Boulevard,', 'StreetNamePostType'), ('Glenview,', 'BuildingName'), ('Northfield', 'BuildingName'), ('Township,', 'BuildingName'), ('Cook', 'BuildingName'), ('County,', 'BuildingName'), ('Illinois,', 'BuildingName'), ('60026,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '3502, Plantation Grove Boulevard, Sharyland Plantation, Mission, Hidalgo County, Texas, 78572, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  3502, Plantation Grove Boulevard, Sharyland Plantation, Mission, Hidalgo County, Texas, 78572, United States
# PARSED TOKENS:    [('3502,', 'AddressNumber'), ('Plantation', 'StreetName'), ('Grove', 'StreetName'), ('Boulevard,', 'StreetNamePostType'), ('Sharyland', 'BuildingName'), ('Plantation,', 'BuildingName'), ('Mission,', 'BuildingName'), ('Hidalgo', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('78572,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '28, Bradley Place, Closter, Bergen County, New Jersey, 07624, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  28, Bradley Place, Closter, Bergen County, New Jersey, 07624, United States
# PARSED TOKENS:    [('28,', 'AddressNumber'), ('Bradley', 'StreetName'), ('Place,', 'StreetNamePostType'), ('Closter,', 'Recipient'), ('Bergen', 'Recipient'), ('County,', 'Recipient'), ('New', 'Recipient'), ('Jersey,', 'Recipient'), ('07624,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'Core Optimal Health Solutions, 14300, North Northsight Boulevard, Scottsdale, Maricopa County, Arizona, 85260, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  Core Optimal Health Solutions, 14300, North Northsight Boulevard, Scottsdale, Maricopa County, Arizona, 85260, United States
# PARSED TOKENS:    [('Core', 'Recipient'), ('Optimal', 'Recipient'), ('Health', 'Recipient'), ('Solutions,', 'Recipient'), ('14300,', 'AddressNumber'), ('North', 'StreetNamePreDirectional'), ('Northsight', 'StreetName'), ('Boulevard,', 'StreetNamePostType'), ('Scottsdale,', 'Recipient'), ('Maricopa', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85260,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '12814, Spirit Mound Lane, Beringer Place at Lake Magnolia, Harris County, Texas, 77346, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  12814, Spirit Mound Lane, Beringer Place at Lake Magnolia, Harris County, Texas, 77346, United States
# PARSED TOKENS:    [('12814,', 'AddressNumber'), ('Spirit', 'StreetName'), ('Mound', 'StreetName'), ('Lane,', 'StreetNamePostType'), ('Beringer', 'BuildingName'), ('Place', 'BuildingName'), ('at', 'BuildingName'), ('Lake', 'BuildingName'), ('Magnolia,', 'BuildingName'), ('Harris', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('77346,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '1931, Euclid Avenue, Lowest Greenville, Dallas, Dallas County, Texas, 75206, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1931, Euclid Avenue, Lowest Greenville, Dallas, Dallas County, Texas, 75206, United States
# PARSED TOKENS:    [('1931,', 'AddressNumber'), ('Euclid', 'StreetName'), ('Avenue,', 'StreetNamePostType'), ('Lowest', 'BuildingName'), ('Greenville,', 'BuildingName'), ('Dallas,', 'BuildingName'), ('Dallas', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('75206,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '5405, Carbine Circle, Bee Cave, Travis County, Texas, 78738, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  5405, Carbine Circle, Bee Cave, Travis County, Texas, 78738, United States
# PARSED TOKENS:    [('5405,', 'AddressNumber'), ('Carbine', 'StreetName'), ('Circle,', 'StreetNamePostType'), ('Bee', 'BuildingName'), ('Cave,', 'BuildingName'), ('Travis', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('78738,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '5, Burlington Avenue, Leonardo, Middletown Township, Monmouth County, New Jersey, 07737, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  5, Burlington Avenue, Leonardo, Middletown Township, Monmouth County, New Jersey, 07737, United States
# PARSED TOKENS:    [('5,', 'AddressNumber'), ('Burlington', 'StreetName'), ('Avenue,', 'StreetNamePostType'), ('Leonardo,', 'Recipient'), ('Middletown', 'Recipient'), ('Township,', 'Recipient'), ('Monmouth', 'Recipient'), ('County,', 'Recipient'), ('New', 'Recipient'), ('Jersey,', 'Recipient'), ('07737,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'Farnam Financial, 2415, East Camelback Road, Colony Biltmore IV, Phoenix, Maricopa County, Arizona, 85016, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  Farnam Financial, 2415, East Camelback Road, Colony Biltmore IV, Phoenix, Maricopa County, Arizona, 85016, United States
# PARSED TOKENS:    [('Farnam', 'BuildingName'), ('Financial,', 'BuildingName'), ('2415,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Camelback', 'StreetName'), ('Road,', 'StreetNamePostType'), ('Colony', 'BuildingName'), ('Biltmore', 'BuildingName'), ('IV,', 'BuildingName'), ('Phoenix,', 'BuildingName'), ('Maricopa', 'BuildingName'), ('County,', 'BuildingName'), ('Arizona,', 'BuildingName'), ('85016,', 'BuildingName'), ('United', 'CountryName'), ('States', 'CountryName')]
# UNCERTAIN LABEL:  BuildingName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'TITLE Boxing Club Paradise Valley, 4848, East Cactus Road, Village Fairways, Phoenix, Maricopa County, Arizona, 85254, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  TITLE Boxing Club Paradise Valley, 4848, East Cactus Road, Village Fairways, Phoenix, Maricopa County, Arizona, 85254, United States
# PARSED TOKENS:    [('TITLE', 'BuildingName'), ('Boxing', 'BuildingName'), ('Club', 'BuildingName'), ('Paradise', 'BuildingName'), ('Valley,', 'BuildingName'), ('4848,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Cactus', 'StreetName'), ('Road,', 'StreetNamePostType'), ('Village', 'BuildingName'), ('Fairways,', 'BuildingName'), ('Phoenix,', 'BuildingName'), ('Maricopa', 'BuildingName'), ('County,', 'BuildingName'), ('Arizona,', 'BuildingName'), ('85254,', 'BuildingName'), ('United', 'CountryName'), ('States', 'CountryName')]
# UNCERTAIN LABEL:  BuildingName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '1412, Lomas Boulevard Northwest, Old Town, Albuquerque, Bernalillo County, New Mexico, 87104, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  1412, Lomas Boulevard Northwest, Old Town, Albuquerque, Bernalillo County, New Mexico, 87104, United States
# PARSED TOKENS:    [('1412,', 'AddressNumber'), ('Lomas', 'StreetName'), ('Boulevard', 'StreetNamePostType'), ('Northwest,', 'StreetNamePostDirectional'), ('Old', 'Recipient'), ('Town,', 'Recipient'), ('Albuquerque,', 'Recipient'), ('Bernalillo', 'Recipient'), ('County,', 'Recipient'), ('New', 'Recipient'), ('Mexico,', 'Recipient'), ('87104,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '2375, East Sunnyside Road, Kingswood Plaza, Idaho Falls, Bonneville County, Idaho, 83404, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  2375, East Sunnyside Road, Kingswood Plaza, Idaho Falls, Bonneville County, Idaho, 83404, United States
# PARSED TOKENS:    [('2375,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Sunnyside', 'StreetName'), ('Road,', 'StreetNamePostType'), ('Kingswood', 'BuildingName'), ('Plaza,', 'BuildingName'), ('Idaho', 'BuildingName'), ('Falls,', 'BuildingName'), ('Bonneville', 'BuildingName'), ('County,', 'BuildingName'), ('Idaho,', 'BuildingName'), ('83404,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'The UPS Store, 14747, North Northsight Boulevard, Scottsdale, Maricopa County, Arizona, 85260, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  The UPS Store, 14747, North Northsight Boulevard, Scottsdale, Maricopa County, Arizona, 85260, United States
# PARSED TOKENS:    [('The', 'Recipient'), ('UPS', 'Recipient'), ('Store,', 'Recipient'), ('14747,', 'AddressNumber'), ('North', 'StreetNamePreDirectional'), ('Northsight', 'StreetName'), ('Boulevard,', 'StreetNamePostType'), ('Scottsdale,', 'Recipient'), ('Maricopa', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85260,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '6024, South Paris Place, Greenwood Village, Arapahoe County, Colorado, 80111, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  6024, South Paris Place, Greenwood Village, Arapahoe County, Colorado, 80111, United States
# PARSED TOKENS:    [('6024,', 'AddressNumber'), ('South', 'StreetNamePreDirectional'), ('Paris', 'StreetName'), ('Place,', 'StreetNamePostType'), ('Greenwood', 'BuildingName'), ('Village,', 'BuildingName'), ('Arapahoe', 'BuildingName'), ('County,', 'BuildingName'), ('Colorado,', 'BuildingName'), ('80111,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'Bainbridge Island Post Office, 271, Winslow Way East, Winslow, Bainbridge Island, Kitsap County, Washington, 98110, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  Bainbridge Island Post Office, 271, Winslow Way East, Winslow, Bainbridge Island, Kitsap County, Washington, 98110, United States
# PARSED TOKENS:    [('Bainbridge', 'BuildingName'), ('Island', 'BuildingName'), ('Post', 'BuildingName'), ('Office,', 'BuildingName'), ('271,', 'AddressNumber'), ('Winslow', 'StreetName'), ('Way', 'StreetNamePostType'), ('East,', 'StreetNamePostDirectional'), ('Winslow,', 'BuildingName'), ('Bainbridge', 'BuildingName'), ('Island,', 'BuildingName'), ('Kitsap', 'BuildingName'), ('County,', 'BuildingName'), ('Washington,', 'BuildingName'), ('98110,', 'BuildingName'), ('United', 'BuildingName'), ('States', 'BuildingName')]
# UNCERTAIN LABEL:  BuildingName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '18731, Walden Glen Circle, Walden Green, Atascocita, Harris County, Texas, 77346, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  18731, Walden Glen Circle, Walden Green, Atascocita, Harris County, Texas, 77346, United States
# ...
# PARSED TOKENS:    [('Stoney', 'BuildingName'), ('Built,', 'BuildingName'), ('5304,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Southern', 'StreetName'), ('Avenue,', 'StreetNamePostType'), ('Mesa,', 'BuildingName'), ('Maricopa', 'BuildingName'), ('County,', 'BuildingName'), ('Arizona,', 'BuildingName'), ('85206,', 'BuildingName'), ('United', 'CountryName'), ('States', 'CountryName')]
# UNCERTAIN LABEL:  BuildingName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '4901, Lyndon B Johnson Freeway, Inwood, Dallas, Dallas County, Texas, 75244, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  4901, Lyndon B Johnson Freeway, Inwood, Dallas, Dallas County, Texas, 75244, United States
# PARSED TOKENS:    [('4901,', 'AddressNumber'), ('Lyndon', 'StreetName'), ('B', 'OccupancyIdentifier'), ('Johnson', 'BuildingName'), ('Freeway,', 'BuildingName'), ('Inwood,', 'BuildingName'), ('Dallas,', 'BuildingName'), ('Dallas', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('75244,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'Stoney Built, 5304, East Southern Avenue, Mesa, Maricopa County, Arizona, 85206, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  Stoney Built, 5304, East Southern Avenue, Mesa, Maricopa County, Arizona, 85206, United States
# PARSED TOKENS:    [('Stoney', 'BuildingName'), ('Built,', 'BuildingName'), ('5304,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Southern', 'StreetName'), ('Avenue,', 'StreetNamePostType'), ('Mesa,', 'BuildingName'), ('Maricopa', 'BuildingName'), ('County,', 'BuildingName'), ('Arizona,', 'BuildingName'), ('85206,', 'BuildingName'), ('United', 'CountryName'), ('States', 'CountryName')]
# UNCERTAIN LABEL:  BuildingName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'Stanford Place II (7979), 7979, East Tufts Avenue, Denver Tech Center, Denver, Colorado, 80237, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  Stanford Place II (7979), 7979, East Tufts Avenue, Denver Tech Center, Denver, Colorado, 80237, United States
# PARSED TOKENS:    [('Stanford', 'BuildingName'), ('Place', 'BuildingName'), ('II', 'BuildingName'), ('(7979),', 'BuildingName'), ('7979,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Tufts', 'StreetName'), ('Avenue,', 'StreetNamePostType'), ('Denver', 'BuildingName'), ('Tech', 'BuildingName'), ('Center,', 'BuildingName'), ('Denver,', 'BuildingName'), ('Colorado,', 'BuildingName'), ('80237,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  BuildingName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'Loves Garage Doors, 6424, East Greenway Parkway, Sunset Ridge I, Scottsdale, Maricopa County, Arizona, 85254, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  Loves Garage Doors, 6424, East Greenway Parkway, Sunset Ridge I, Scottsdale, Maricopa County, Arizona, 85254, United States
# PARSED TOKENS:    [('Loves', 'BuildingName'), ('Garage', 'BuildingName'), ('Doors,', 'BuildingName'), ('6424,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Greenway', 'StreetName'), ('Parkway,', 'StreetNamePostType'), ('Sunset', 'BuildingName'), ('Ridge', 'BuildingName'), ('I,', 'BuildingName'), ('Scottsdale,', 'BuildingName'), ('Maricopa', 'BuildingName'), ('County,', 'BuildingName'), ('Arizona,', 'BuildingName'), ('85254,', 'BuildingName'), ('United', 'CountryName'), ('States', 'CountryName')]
# UNCERTAIN LABEL:  BuildingName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'offerCHECK.com, 3303, East Baseline Road, Executive Villas at Dana Point, Gilbert, Maricopa County, Arizona, 85234, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  offerCHECK.com, 3303, East Baseline Road, Executive Villas at Dana Point, Gilbert, Maricopa County, Arizona, 85234, United States
# PARSED TOKENS:    [('offerCHECK.com,', 'BuildingName'), ('3303,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Baseline', 'StreetName'), ('Road,', 'StreetNamePostType'), ('Executive', 'BuildingName'), ('Villas', 'BuildingName'), ('at', 'BuildingName'), ('Dana', 'BuildingName'), ('Point,', 'BuildingName'), ('Gilbert,', 'BuildingName'), ('Maricopa', 'BuildingName'), ('County,', 'BuildingName'), ('Arizona,', 'BuildingName'), ('85234,', 'BuildingName'), ('United', 'CountryName'), ('States', 'CountryName')]
# UNCERTAIN LABEL:  BuildingName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '7706, La Salle Avenue, Bacon Crest, Lubbock, Lubbock County, Texas, 79424, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  7706, La Salle Avenue, Bacon Crest, Lubbock, Lubbock County, Texas, 79424, United States
# PARSED TOKENS:    [('7706,', 'AddressNumber'), ('La', 'StreetName'), ('Salle', 'StreetName'), ('Avenue,', 'StreetNamePostType'), ('Bacon', 'BuildingName'), ('Crest,', 'BuildingName'), ('Lubbock,', 'BuildingName'), ('Lubbock', 'BuildingName'), ('County,', 'BuildingName'), ('Texas,', 'BuildingName'), ('79424,', 'AddressNumber'), ('United', 'StreetName'), ('States', 'StreetName')]
# UNCERTAIN LABEL:  AddressNumber
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address '81, Willowbrook Circle, Johnston County, North Carolina, 27527, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  81, Willowbrook Circle, Johnston County, North Carolina, 27527, United States
# PARSED TOKENS:    [('81,', 'AddressNumber'), ('Willowbrook', 'StreetName'), ('Circle,', 'StreetNamePostType'), ('Johnston', 'SubaddressIdentifier'), ('County,', 'SubaddressType'), ('North', 'SubaddressIdentifier'), ('Carolina,', 'SubaddressType'), ('27527,', 'SubaddressIdentifier'), ('United', 'CountryName'), ('States', 'CountryName')]
# UNCERTAIN LABEL:  SubaddressIdentifier
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'offerCHECK.com, 3303, East Baseline Road, Executive Villas at Dana Point, Gilbert, Maricopa County, Arizona, 85234, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  offerCHECK.com, 3303, East Baseline Road, Executive Villas at Dana Point, Gilbert, Maricopa County, Arizona, 85234, United States
# PARSED TOKENS:    [('offerCHECK.com,', 'BuildingName'), ('3303,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Baseline', 'StreetName'), ('Road,', 'StreetNamePostType'), ('Executive', 'BuildingName'), ('Villas', 'BuildingName'), ('at', 'BuildingName'), ('Dana', 'BuildingName'), ('Point,', 'BuildingName'), ('Gilbert,', 'BuildingName'), ('Maricopa', 'BuildingName'), ('County,', 'BuildingName'), ('Arizona,', 'BuildingName'), ('85234,', 'BuildingName'), ('United', 'CountryName'), ('States', 'CountryName')]
# UNCERTAIN LABEL:  BuildingName
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Error parsing address 'MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States':
# ERROR: Unable to tag this string because more than one area of the string has the same label
#
# ORIGINAL STRING:  MAXCOM, 1846, East Innovation Park Drive, Ventana Medical Systems Inc., Oro Valley, Pima County, Arizona, 85755, United States
# PARSED TOKENS:    [('MAXCOM,', 'Recipient'), ('1846,', 'AddressNumber'), ('East', 'StreetNamePreDirectional'), ('Innovation', 'StreetName'), ('Park', 'StreetName'), ('Drive,', 'StreetNamePostType'), ('Ventana', 'Recipient'), ('Medical', 'Recipient'), ('Systems', 'Recipient'), ('Inc.,', 'Recipient'), ('Oro', 'Recipient'), ('Valley,', 'Recipient'), ('Pima', 'Recipient'), ('County,', 'Recipient'), ('Arizona,', 'Recipient'), ('85755,', 'Recipient'), ('United', 'Recipient'), ('States', 'Recipient')]
# UNCERTAIN LABEL:  Recipient
#
# When this error is raised, it's likely that either (1) the string is not a valid person/corporation name or (2) some tokens were labeled incorrectly
#
# To report an error in labeling a valid name, open an issue at https://github.com/datamade/usaddress/issues/new - it'll help us continue to improve probablepeople!
#
# For more information, see the documentation at https://usaddress.readthedocs.io/
# Exported parsed data to: /Users/bryanevan/Downloads/Phoenix_forecasa_parsed.csv_test.csv

# %%
def main():
    suffix_regex_pattern = compile_street_suffix_regex(suffix_file_path)
    states_set = load_states_data(states_json_path)
    parsed_df = parse_address_data(file_path, suffix_regex_pattern, cities_aliases_path, states_set)
    new_file_path = export_parsed_data(parsed_df, file_path, directory_path)
    print(f"Exported parsed data to: {new_file_path}")

# %%
# %timeit -r 3 -n 10 main()

# %%
# %prun -s cumtime main()
